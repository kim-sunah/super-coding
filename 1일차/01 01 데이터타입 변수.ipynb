# %% [markdown]
# ## <b>데이터 타입</b>
#
# 파이썬에서 데이터 리터럴은 크게 다음과 같은 유형이 있다
# * 숫자(Number) - int, float
# * 문자열(Text) - str
# * 논리값(Boolean) - bool
# * 복합객체(Collectable) - list, dict, tuple, set
#
# 각각의 유형별로 자세히 아래에서 살펴본다

# %% [markdown]
# ## <b>1. 변수(Variable)</b>
# * 변수는 숫자나 문자 같은 <b>데이터 값을 저장하는 그릇</b>과 같다
# * 변수의 선언 및 초기화는 변수의 값을 할당 할 때 이루어 진다
# * 변수의 값은 등호 "="를 이용해서 할당한다

# %%
year = 2025
month = 1
day = 31
print(year, month, day)

# %% [markdown]
# * 선언되지 않은 변수를 사용하면 에러가 발생한다

# %%
print(birthday)

# %% [markdown]
# #### <b>변수의 이름 규칙</b>
#
# * 변수이름은 알파벳(A-z), 숫자(0-9), 그리고 언더스코어('_')를 포함할 수 있다
#   * 변수이름에 한글을 사용할 수는 있지만, 일반적으로 한글을 변수이름에 사용하는 것은 비추한다.
# * 변수이름은 문자와 언더스코어로 시작할수 있다.
# * 하지만, 변수이름은 숫자로는 시작할 수 없다
# * 변수 이름은 대소문자 구분을 한다
# * 파이썬의 키워드(if, then, import, def, 등 등)는 변수 이름으로 사용할 수 없다
# * 선언된 변수의 이름은 바꿀 수 없다

# %% [markdown]
# #### <b>올바른 변수 이름 예시<b>

# %%
myName = "John Smith"       # 카멜 표기법(Camel Case)
MyName = "John Smith"       # 파스칼 표기법(Pascal Case)
my_name = "John Smith"      # 스네이크 표기법(Snake Case)
_my_name = "Join Smith"
_myname = "John Smith"
myname = "John Smith"
MYNAME = "John Smith"
__myname__ = "john Smith"
myname2 = "John Smith"
my_2nd_name = "John Smith"
_ = "any data"
# Out:
# any data

# %% [markdown]
# #### <b> 잘못된 변수 이름 예시</b>

# %%
2nd_name = "John Smith"     #숫자로 시작
my-name = "John Smith"      #'-'포함
my name = "John Smith"      #중간에 스페이스
pass = "John Smith"         #pass는 파이썬 키워드

# %% [markdown]
# #### <b>변수에 데이터 리터럴 값 할당 하는 방법들</b>

# %%
year = 2025
month = 5
day = 15
print(year, month, day)

# %%
# 여러 변수값 한번에 초기화
year, month, day = 2025, 5, 15
print(year, month, day)

# %%
# 다른 자료형 데이터를 한번에 설정
name, age, height = "John Smith", 24, 174.5
print(name, age, height)

# %%
# 다른 변수의 값을 가져오기
data1 = 100
data2 = data1
print(data2, type(data2))

# %%
# 계산 값을 변수에 할당 하기
x, y = 10, 20
result = x + y + 30
print(result)

# %%
# 자기 값에 1을 더하기
x = 10
x = x + 10
print(x)

# 자기 값에 1을 빼기
x = x - 1
print(x)

# %%
# 파이썬에서는 위의 표현을 다음과 같이 할 수 있다
x = 10
x += 10  # x = x + 1
print(x)

x -= 1  # x = x - 1
print(x)

# %%
# 두개의 변수 값을 서로 바꾸기 (일반적인 방법)
a = 10
b = 20

_ = a
a = b
b = _
print(a, b)

# %%
# 두개의 변수 값을 서로 바꾸기 (파이썬에서만 가능한 방법)
a = 10
b = 20

a, b = b, a
print(a, b)

# %% [markdown]
# #### <b>변수 값 출력 및 입력</b>
#
# * print( ) : 변수 값 화면에 출력
# * input( ) : 변수 값 키보드로 입력 받기

# %%
# 변수 값 출력
name = "홍길동"
age = 24

print(name)
print(age)
print(name, age)
print("이름:", name, ", 나이:", age)

# %%
# 변수 값 직접 입력 받기
name = input()
print(name, type(name))

age = int(input())
print(age, type(age))

# %%
# 변수 값 입력받을때 정보 출력하고 입력받기
name = input("이름을 입력하세요:")
age = int(input("나이를 입력하세요:"))

print("이름:", name, ", 나이:", age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 변수 값 입력받을때 정보 출력하고 입력받기
#       2 name = input("이름을 입력하세요:")
# ----> 3 age = int(input("나이를 입력하세요:"))
#       5 print("이름:", name, ", 나이:", age)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# #### <b>변수 삭제</b>

# %%
# 변수 값을 삭제하는 경우
number = 100
number = None
print(number)

# %%
# 변수 자체를 삭제하는 경우
number = 100
del number
# 변수 자체가 삭제 되었으므로 변수를 사용하려고 하면 에러가 난다
print(number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 del number
#       4 # 변수 자체가 삭제 되었으므로 변수를 사용하려고 하면 에러가 난다
# ----> 5 print(number)
#
# NameError: name 'number' is not defined

# %% [markdown]
# #### <b>변수 연습 문제 1</b>
#
# * 아래와 같은 형식으로 출력되도록 변수에 값을 할당하여 초기화 하세요
# * 아래 print 문은 건드리지 마세요.
# * 이름과, 성별, 나이, 키, 주소 등은 실제 본인의 정보를 사용하셔도 되고 임의의 값을 사용하셔도 괜찮습니다.
#
#
# ```
# 이름: 홍길동
# 성별: 남자
# 나이: 24
# 키: 178.5
# 주소: 서울시 강남구 도곡로 1길 10
# 이메일: jdhong@gmail.com
# ```

# %%
############################
# 여기에 변수를 초기화 하세요
name = '홍길동'
sex = '남자'
age = 24
height = 178.5
address='서울시 강남구 도곡로 1길 10'
email ='jdhong@gmail.com'
#############################

print("이름:", name)
print("성별:", sex)
print("나이:", age)
print("키:", height)
print("주소:", address)
print("이메일:", email)
# Out:
# 이름: 홍길동
# 성별: 남자
# 나이: 24
# 키: 178.5
# 주소: 서울시 강남구 도곡로 1길 10
# 이메일: jdhong@gmail.com

# %% [markdown]
# #### 연습문제 1 정답 <b>(미리 열어보지 마세요)</b>

# %%
############################
# 여기에 변수를 초기화 하세요
myName = "홍길동"
sex = "남자"
age = 24
height = 178.5
address = "서울시 강남구 도곡로 1길 10"
email = "jdhong@gmail.com"
#############################

print("이름:", myName)
print("성별:", sex)
print("나이:", age)
print("키:", height)
print("주소:", address)
print("이메일:", email)

# %% [markdown]
# #### <b>변수 연습 문제 2</b>
#
# * 두 개의 변수 `x`와 `y`에 각각 10과 20을 할당합니다.
# * `x`와 `y`의 값을 서로 바꿔서 출력하세요.
# * 단, 임시 변수를 사용하지 않고 파이썬의 특징을 활용하여 값을 바꿔야 합니다.

# %%
# 아래에 코드를 작성하세요.

x, y = 10, 20
x, y = x, y

print("x:", x)
print("y:", y)
# Out:
# x: 10
# y: 20

# %% [markdown]
# #### <b>변수 연습 문제 3</b>
#
# * 사용자로부터 이름과 나이를 입력받아 각각 `name`과 `age` 변수에 저장합니다.
# * 입력받은 이름과 나이를 다음과 같은 형식으로 출력하세요.
#
# ```
# 이름: [이름], 나이: [나이]
# ```

# %%
# 아래에 코드를 작성하세요.

name = input("이름을 입력하세요:")
age = input("나이를 입력하세요:")

print(f"이름: [{name}], 나이: [{age}]")
# Out:
# 이름: [ㅇㄹㅇㄹ],나이: [12]

# %% [markdown]
# #### <b>변수 연습 문제 4</b>
#
# * 변수 `radius`에 원의 반지름을 저장하고, 변수 `area`에 원의 넓이를 계산하여 저장합니다.
# * 원주율은 3.141592로 사용합니다.
# * 원의 넓이를 출력하세요.
# * 반지름은 input() 함수를 사용하여 사용자로부터 입력받으세요.

# %%
# 아래에 코드를 작성하세요.
import math

radius = int(input('반지름'))
area =  (radius*2) * 3.141592

print("원의 넓이:", area)
# Out:
# 원의 넓이: 615.752032

# %% [markdown]
# #### <b>변수 연습 문제 5</b>
#
# * 두 개의 정수를 입력받아 변수 `num1`과 `num2`에 저장합니다.
# * 두 수의 합, 차, 곱, 몫, 나머지를 각각 계산하여 출력합니다.

# %%
# 아래에 코드를 작성하세요.
num1 = int(input('num1'))
num2 = int(input('num2'))

print("두 수의 합:", num1+num2)
print("두 수의 차:", num1-num2)
print("두 수의 곱:", num1*num2)
print("두 수의 몫:", num1/num2)
print("두 수의 나머지:", num1%num2)
# Out:
# 두 수의 합: 6
# 두 수의 차: 2
# 두 수의 곱: 8
# 두 수의 몫: 2.0
# 두 수의 나머지: 0

# %% [markdown]
# #### 연습문제 2 ~ 5 정답 <b>(미리 열어보지 마세요)</b>

# %%
# #### <b>변수 연습 문제 2</b>
#
# * 두 개의 변수 `x`와 `y`에 각각 10과 20을 할당합니다.
# * `x`와 `y`의 값을 서로 바꿔서 출력하세요.
# * 단, 임시 변수를 사용하지 않고 파이썬의 특징을 활용하여 값을 바꿔야 합니다.

# 아래에 코드를 작성하세요.
x = 10
y = 20

# x와 y의 값을 서로 바꾸는 코드를 작성하세요.
x, y = y, x


print("x:", x)
print("y:", y)

# %%
# #### <b>변수 연습 문제 3</b>
#
# * 사용자로부터 이름과 나이를 입력받아 각각 `name`과 `age` 변수에 저장합니다.
# * 입력받은 이름과 나이를 다음과 같은 형식으로 출력하세요.
#
# ```
# 이름: [이름], 나이: [나이]
# ```

# 아래에 코드를 작성하세요.
name = input("이름을 입력하세요: ")
age = input("나이를 입력하세요: ")

print(f"이름: {name}, 나이: {age}")

# %%
# #### <b>변수 연습 문제 4</b>
#
# * 변수 `radius`에 원의 반지름을 저장하고, 변수 `area`에 원의 넓이를 계산하여 저장합니다.
# * 원주율은 3.141592로 사용합니다.
# * 원의 넓이를 출력하세요.
# * 반지름은 input() 함수를 사용하여 사용자로부터 입력받으세요.

# 아래에 코드를 작성하세요.

radius = float(input("원의 반지름을 입력하세요: "))
pi = 3.141592
area = pi * (radius ** 2)

print("원의 넓이:", area)

# %%
# #### <b>변수 연습 문제 5</b>
#
# * 두 개의 정수를 입력받아 변수 `num1`과 `num2`에 저장합니다.
# * 두 수의 합, 차, 곱, 몫, 나머지를 각각 계산하여 출력합니다.

# 아래에 코드를 작성하세요.
num1 = int(input("첫 번째 정수를 입력하세요: "))
num2 = int(input("두 번째 정수를 입력하세요: "))

print("두 수의 합:", num1 + num2)
print("두 수의 차:", num1 - num2)
print("두 수의 곱:", num1 * num2)
print("두 수의 몫:", num1 // num2)
print("두 수의 나머지:", num1 % num2)
